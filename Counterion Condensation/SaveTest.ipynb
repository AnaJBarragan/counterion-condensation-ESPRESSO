# %% [markdown]
# Testing boop boop

# %%
print("I am runnable code that saves and doesnt disappear when closing Docker")
# Out:
# I am runnable code that saves and doesnt disappear when closing Docker
